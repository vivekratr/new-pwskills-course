# %%
import bokeh.io as bo
import bokeh.plotting as bp
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers
bo.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1006">Loading BokehJS ...</span>
#     </div>

# %%
output_file('test.html')

# %%
p = figure(title = 'my first bokeh')
p.xaxis.axis_label='petal length'
p.yaxis.axis_label='petal width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="644413dd-37b3-4b5d-b704-31de4ebd3ec8" data-root-id="p1101" style="display: contents;"></div>

# %%
p = figure(title = 'my first bokeh')
p.xaxis.axis_label='petal length'
p.yaxis.axis_label='petal width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="ea69198d-c08f-4764-a87e-8a6cdeafb61a" data-root-id="p1396" style="display: contents;"></div>
